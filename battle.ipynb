# %%
import json
import pandas as pd

# %%
with open("battle.json") as f:
    data = json.loads(f.read())

data
# Out:
# {'id': 'gen9randombattle-1847953923',
#  'p1': 'pokeblade☆101',
#  'p2': 'MichaelderBeste2',
#  'format': '[Gen 9] Random Battle',
# ...

# %%
log = data['log'].split('\n')
for line in log:
    print(line)
# Out:
# |j|☆pokeblade☆101
# |j|☆MichaelderBeste2
# |t:|1682015480
# |gametype|singles
# |player|p1|pokeblade☆101|#rbtt6teamyveltal|2398
# |player|p2|MichaelderBeste2|#rbtt6teamlatias|2423
# |teamsize|p1|6
# |teamsize|p2|6
# |gen|9
# |tier|[Gen 9] Random Battle
# |rated|
# |rule|Species Clause: Limit one of each Pokémon
# |rule|HP Percentage Mod: HP is shown in percentages
# |rule|Sleep Clause Mod: Limit one foe put to sleep
# |
# |t:|1682015480
# |start
# |switch|p1a: Carbink|Carbink, L89|234/234
# |switch|p2a: Klefki|Klefki, L84, M|233/233
# |turn|1
# |j| Why are you fat?
# |c|☆MichaelderBeste2|hf
# |
# |t:|1682015492
# |move|p2a: Klefki|Spikes|p1a: Carbink
# |-sidestart|p1: pokeblade☆101|Spikes
# |move|p1a: Carbink|Body Press|p2a: Klefki
# |-crit|p2a: Klefki
# |-damage|p2a: Klefki|103/233
# |
# |-heal|p2a: Klefki|117/233|[from] item: Leftovers
# |upkeep
# |turn|2
# |
# |t:|1682015503
# |switch|p2a: Kilowattrel|Kilowattrel, L83, F|252/252
# |move|p1a: Carbink|Body Press|p2a: Kilowattrel
# ...
